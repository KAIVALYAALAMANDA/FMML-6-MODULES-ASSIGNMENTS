# %% [markdown]
# <a href="https://colab.research.google.com/github/KAIVALYAALAMANDA/FMML-ALL-MODULES-ASSIGNMENTS/blob/main/MODULE_8%20Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-16 17:10:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   112MB/s    in 0.6s
#
# 2023-06-16 17:10:57 (112 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39030  1612.03373v1  There is a trend to acquire high accuracy land...  stat
# 3791   1606.05228v1  The difficulty of multi-class classification g...  stat
# 9811    1301.2320v1  We treat collaborative filtering as a univaria...    cs
# 28350  1706.03114v1  Large collections of videos are grouped into c...    cs
# 7078   1709.10323v1  A recent theoretical analysis shows the equiva...  stat
# ...             ...                                                ...   ...
# 2302   1802.08679v1  Choosing optimal (or at least better) policies...    cs
# 39632  1611.00287v2  Structured illumination microscopy (SIM) impro...    cs
# 22428  1606.08105v1  When observations are organized into groups wh...  stat
# 19172   1304.1526v1  A number of algorithms have been developed to ...    cs
# 9678   1609.09432v1  There is a growing interest in joint multi-sub...  stat
#
#                                                    title  year  \
# 39030  A probabilistic graphical model approach in 30...  2016
# 3791   How many faces can be recognized? Performance ...  2016
# 9811      Using Temporal Data for Making Recommendations  2013
# 28350  Collaborative Summarization of Topic-Related V...  2017
# 7078   A Nonlinear Orthogonal Non-Negative Matrix Fac...  2017
# ...                                                  ...   ...
# 2302   Learning Optimal Policies from Observational Data  2018
# 39632  Structured illumination microscopy with unknow...  2016
# 22428  The Dependent Random Measures with Independent...  2016
# 19172  Simulation Approaches to General Probabilistic...  2013
# 9678   A Searchlight Factor Model Approach for Locati...  2016
#
#                                                 keywords
# 39030  [classification, especially, probabilistic, gr...
# 3791   [difficulty, classification, generally, increa...
# 9811   [collaborative, filtering, univariate, estimat...
# 28350  [collections, important, repeating, topically,...
# 7078   [theoretical, equivalence, factorization, clus...
# ...                                                  ...
# 2302   [important, education, controlled, experiments...
# 39632  [structured, illumination, microscopy, resolut...
# 22428  [observations, organized, commonalties, depend...
# 19172  [algorithms, developed, probabilistic, inferen...
# 9678   [challenge, anatomical, functional, variabilit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39030    [classification, especially, probabilistic, gr...
# 3791     [difficulty, classification, generally, increa...
# 9811     [collaborative, filtering, univariate, estimat...
# 28350    [collections, important, repeating, topically,...
# 7078     [theoretical, equivalence, factorization, clus...
#                                ...
# 21423    [integrated, challenging, sequential, strategi...
# 34592    [transform, mediterranean, characteristics, vi...
# 25745    [introduce, answering, recurrent, structures, ...
# 25363    [understanding, specifically, instances, furni...
# 22478    [pipelines, typically, optimization, technique...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8712 words.
# Out of those 4597 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="53e94b4b-d9ed-43d0-98e8-b85de6d06ca9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53e94b4b-d9ed-43d0-98e8-b85de6d06ca9")) {                    Plotly.newPlot(                        "53e94b4b-d9ed-43d0-98e8-b85de6d06ca9",                        [{"x":["administrative","generated","information","independent","advantages","accuracies","probability","spectroradiometer","reliability","resolution","classifiers","comparison","probabilistic","selectively","respectively","graphical","improvements","estimation","quantitative","conditional","effectiveness","classification","especially","distributions","recognition","simulations","performance","assumption","theoretical","asymptotics","investigate","generally","classifier","generative","extrapolation","difficulty","recognized","increased","estimated","increases","pseudolikelihood","distribution","foundation","robustness","character","dimensional","recommend","approaches","filtering","univariate","predictive","recommendations","transforming","algorithms","collaborative","important","quadratic","algorithm","techniques","collections","typically","exploiting","challenging","simultaneously","identified","intuition","demonstrate","summarization","processing","influence","summarize","optimization","developing","summarized","attributes","repeating","experiments","efficiently","minimization","attribute","retrieval","equivalence","essentially","connection","structure","geometric","intrinsic","framework","normalized","regularization","introduce","orthogonality","clustering","nonlinear","considerably","factorization","establish","multiplicative","orthogonal","prediction","effective","covariate","distributional","regression","assumptions","situation","dimension","converges","polynomial","construct","facilitate","evaluating","computational","efficient","necessary","constructed","arguments","reasoning","presented","assimilation","structured","environment","knowledge","propagation","constructing","sequential","continuously","predicted","explicitly","significantly","heterogeneity","contextual","formulating","treatments","decisions","physicians","approximation","selection","responses","expensive","informative","replacement","recommended","experiment","assignment","individuals","personalized","maximizing","incorporate","potential","treatment","individual","relationship","incorporating","experimentally","uncertainty","challenges","digitally","different","differential","satisfies","interaction","inference","involving","preserving","variables","centralized","formulate","posterior","precision","guarantees","methodology","scientists","influences","dependence","dependency","measuring","accordingly","complexity","numerical","shortcomings","statistical","dependencies","disciplines","literature","estimators","detecting","realization","introduces","theoretic","coefficients","extraction","developed","separately","histogram","component","laboratory","improvement","technique","cognitive"],"y":[1,164,715,125,83,28,162,0,26,114,120,143,155,11,87,40,104,221,72,104,210,469,123,127,367,43,865,65,155,1,153,68,148,135,1,46,17,33,72,43,0,203,8,90,60,179,4,431,58,5,59,14,9,550,33,354,36,788,347,24,101,73,271,106,35,18,536,33,315,56,22,299,63,2,61,3,612,178,53,36,116,25,24,43,337,60,34,569,28,77,325,1,143,62,32,37,54,10,18,246,249,7,19,133,80,39,60,24,67,99,48,63,301,407,75,61,22,135,176,2,112,137,361,64,47,79,17,48,73,271,6,57,11,9,54,2,108,168,32,58,26,6,3,71,27,35,17,21,58,167,24,105,73,61,56,82,104,1,761,28,10,92,197,40,56,101,9,56,43,86,54,73,10,15,29,45,42,20,209,84,10,160,58,8,118,14,67,5,57,48,35,154,182,31,20,94,11,155,230,50],"type":"bar"},{"x":["administrative","generated","information","independent","advantages","accuraci ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4597,), (4597, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.825

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>Modeling</span> <span style=''>of</span> <span style=''>Seed</span> <span style=''>Variety</span> <span style=''>Yields</span> <span style=''>and</span> <span style=''>Decision</span> <span style=''>Making</span> <span style=''>for</span> <span style=''>Future</span> <span style=''>Planting</span> <span style=''>Plans</span> <br/><br/><span style=''>Eradicating</span> <span style=''>hunger</span> <span style=''>and</span> <span style=''>malnutrition</span> <span style=''>is</span> <span style=''>a</span> <span style=''>key</span> <span style='background-color:rgba(0, 255, 0, 0.425531914893617);'>development</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>the</span> <span style=''>21st</span> <span style=''>century</span> <span style=''>We</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>seed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>varieties</span> <span style=''>to</span> <span style=''>reliably</span> <span style=''>increase</span> <span style=''>crop</span> <span style=''>yield</span> <span style=''>within</span> <span style=''>a</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>decision</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.45679012345679015);'>mechanism</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>crop</span> <span style=''>yield</span> <span style=''>(the</span> <span style=''>yield</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.31206896551724145);'>different</span> <span style=''>seed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>varieties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>same</span> <span style=''>crop)</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.41818181818181827);'>integrate</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.45679012345679015);'>mechanism</span> <span style=''>with</span> <span style=''>a</span> <span style=''>weather</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>forecasting</span> <span style=''>model</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.31206896551724145);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>to</span> <span style=''>select</span> <span style=''>seed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>varieties</span> <span style=''>for</span> <span style=''>planting</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>balance</span> <span style=''>yield</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818181);'>maximization</span> <span style=''>and</span> <span style=''>riskWe</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>schemes</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <br/><br/><span style=''>Several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>are</span> <span style=''>studied</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>Laplace</span> <span style=''>method</span> <span style=''>a</span> <span style=''>faster</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>it</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadrature</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>version</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>sampling</span> <span style=''>(ie</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadrature</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>approximation)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>in</span> <span style=''>training</span> <span style=''>linear</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>best</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>sampling</span> <span style=''>while</span> <span style=''>it</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>well</span> <span style=''>using</span> <span style=''>Laplace</span> <span style=''>style</span> <span style=''>methods</span> <span style=''>with</span> <span style=''>smooth</span> <span style=''>factors</span> <span style=''>but</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>be</span> <span style=''>unstable</span> <span style=''>with</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>ones</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadrature</span> <span style=''>yields</span> <span style=''>unstable</span> <span style=''>behavior</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>to</span> <span style=''>a</span> <span style=''>sub</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>in</span> <span style=''>most</span> <span style='background-color ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dynamic</span> <span style=''>Pricing</span> <span style=''>under</span> <span style=''>Finite</span> <span style=''>Space</span> <span style=''>Demand</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uncertainty</span> <span style=''>A</span> <span style=''>Multi</span> <span style=''>Armed</span> <span style=''>Bandit</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style=''>Arms</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>dynamic</span> <span style=''>pricing</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>unknown</span> <span style=''>demand</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>a</span> <span style=''>seller</span> <span style=''>offers</span> <span style=''>prices</span> <span style=''>to</span> <span style=''>a</span> <span style=''>stream</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>customers</span> <span style=''>and</span> <span style=''>observes</span> <span style=''>either</span> <span style=''>success</span> <span style=''>or</span> <span style=''>failure</span> <span style=''>in</span> <span style=''>each</span> <span style=''>sale</span> <span style=''>attempt</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>demand</span> <span style=''>model</span> <span style=''>is</span> <span style=''>unknown</span> <span style=''>to</span> <span style=''>the</span> <span style=''>seller</span> <span style=''>and</span> <span style=''>can</span> <span style=''>take</span> <span style=''>one</span> <span style=''>of</span> <span style=''>N</span> <span style=''>possible</span> <span style=''>forms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulated</span> <span style=''>as</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>arms</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>dynamic</span> <span style=''>pricing</span> <span style=''>policy</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4640000000000001);'>likelihood</span> <span style=''>ratio</span> <span style=''>test</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>policy</span> <span style=''>achieves</span> <span style=''>complete</span> <span style=''>learning</span> <span style=''>ie</span> <span style=''>it</span> <span style=''>offers</span> <span style=''>a</span> <span style=''>bounded</span> <span style=''>regret</span> <span style=''>where</span> <span style=''>regret</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style=''>revenue</span> <span style=''>loss</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>case</span> <span style=''>with</span> <span style=''>a</span> <span style=''>known</span> <span style=''>demand</span> <span style=''>model</span> <span style=''>This</span> <span style=''>is</span> <span style=''>in</span> <span style=''>sharp</span> <span style=''>contrast</span> <span style=''>with</span> <span style=''>the< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learned</span> <span style=''>D</span> <span style=''>AMP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principled</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressive</span> <span style=''>Image</span> <span style=''>Recovery</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Compressive</span> <span style=''>image</span> <span style=''>recovery</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>requires</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>Recently</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>been</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style=''>results</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>massively</span> <span style=''>parallel</span> <span style=''>GPU</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>and</span> <span style=''>oodles</span> <span style=''>of</span> <span style=''>training</span> <span style=''>data</span> <span style=''>they</span> <span style=''>can</span> <span style=''>run</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>magnitude</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>However</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>largely</span> <span style=''>unprincipled</span> <span style=''>black</span> <span style=''>boxes</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>train</span> <span style=''>and</span> <span style=''>often</span> <span style=''>times</span> <span style=''>specific</span> <span style=''>to</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style=''>matrix</span> <span style=''>It</span> <span style=''>was</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>sparse</span> <span style=''>signal</span> <span style=''>recovery</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>be</span> <span style=''>unrolled</span> <span style=''>to</span> <span style=''>form</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>Taking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inspiration</span> <span style=''>from</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>that</span> <span style=''>mimics</span> <span style=''>th ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1294370742201506)
# 	experimental (0.13911796342775187)
# 	architecture (0.08497669415561133)
# 	segmentation (0.0720688418788096)
# 	processing (0.11294370742201507)
# 	detection (0.12334169953388312)
# 	information (0.2563642882753675)
# 	different (0.27285765507350307)
# 	recognition (0.1315883829329509)
# 	convolutional (0.13804230907135173)
#
# Some Statistics words are:
# 	stochastic (0.13823968175037296)
# 	statistical (0.15713575335653904)
# 	theoretical (0.15564395822973645)
# 	estimation (0.17951268025857783)
# 	algorithm (0.38985579313774243)
# 	distribution (0.18349080059671805)
# 	variables (0.147687717553456)
# 	dimensional (0.18547986076578815)
# 	inference (0.19890601690701143)
# 	regression (0.18299353555445053)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a2a72b96-763d-4a8b-b164-5da63ff86c09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2a72b96-763d-4a8b-b164-5da63ff86c09")) {                    Plotly.newPlot(                        "a2a72b96-763d-4a8b-b164-5da63ff86c09",                        [{"x":["administrative","generated","information","independent","advantages","accuracies","probability","spectroradiometer","reliability","resolution","classifiers","comparison","probabilistic","selectively","respectively","graphical","improvements","estimation","quantitative","conditional","effectiveness","classification","especially","distributions","recognition","simulations","performance","assumption","theoretical","asymptotics","investigate","generally","classifier","generative","extrapolation","difficulty","recognized","increased","estimated","increases","pseudolikelihood","distribution","foundation","robustness","character","dimensional","recommend","approaches","filtering","univariate","predictive","recommendations","transforming","algorithms","collaborative","important","quadratic","algorithm","techniques","collections","typically","exploiting","challenging","simultaneously","identified","intuition","demonstrate","summarization","processing","influence","summarize","optimization","developing","summarized","attributes","repeating","experiments","efficiently","minimization","attribute","retrieval","equivalence","essentially","connection","structure","geometric","intrinsic","framework","normalized","regularization","introduce","orthogonality","clustering","nonlinear","considerably","factorization","establish","multiplicative","orthogonal","prediction","effective","covariate","distributional","regression","assumptions","situation","dimension","converges","polynomial","construct","facilitate","evaluating","computational","efficient","necessary","constructed","arguments","reasoning","presented","assimilation","structured","environment","knowledge","propagation","constructing","sequential","continuously","predicted","explicitly","significantly","heterogeneity","contextual","formulating","treatments","decisions","physicians","approximation","selection","responses","expensive","informative","replacement","recommended","experiment","assignment","individuals","personalized","maximizing","incorporate","potential","treatment","individual","relationship","incorporating","experimentally","uncertainty","challenges","digitally","different","differential","satisfies","interaction","inference","involving","preserving","variables","centralized","formulate","posterior","precision","guarantees","methodology","scientists","influences","dependence","dependency","measuring","accordingly","complexity","numerical","shortcomings","statistical","dependencies","disciplines","literature","estimators","detecting","realization","introduces","theoretic","coefficients","extraction","developed","separately","histogram","component","laboratory","improvement","technique","cognitive","transformation","integrating","currently","combinational","principal","guarantee","recognizing","particular","extracted","performed","integration","predefined","intensity","afterward","criterion","classified","components","projection","modelisation","facilitating","satisfactory","segmentation","correspond","supervise","artifacts","connected","detection","artefacts","presentons","categories","pedestrians","supervised","invariance","closedness","adaptivity","simulation","estimator","intuitive","protection","controversial","practical","properties","criticized","favorable","conditioned","desirable","postprocessing","partially","calculations","generalization","accurately","magnitude","independence","interesting","composition","perturbation","su ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	spectroradiometer
# 	pseudolikelihood
# 	emphsparse
# 	hyperplane
# 	schizophrenia
# 	methylation
# 	logarithmically
# 	conformalized
# 	underdetermined
# 	overdetermined
# 	neuroscientists
# 	spectroscopy
# 	concordant
# 	circumvents
# 	candecompparafac
# 	flattening
# 	oscillates
# 	coincides
# 	borrowings
# 	regularizes
# Some words which never appear in Statistics papers:
# 	combinational
# 	modelisation
# 	presentons
# 	articulated
# 	articulation
# 	descriptive
# 	designers
# 	hyperedge
# 	interdependencies
# 	stackelberg
# 	conformance
# 	reachability
# 	executions
# 	repairing
# 	soundness
# 	declarative
# 	enforcement
# 	commented
# 	cylindrical
# 	lambertian

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0781543386585404e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7825
